# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False) 
# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
house_df = pd.read_csv('realestate_prices.csv', encoding = 'ISO-8859-1')

# %%
house_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
house_df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
house_df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# 21605         2520      6023     2.0           0     0  ...      9
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21603        2270              0      2003             0    98065  47.5389
# 21604        1490              0      2014             0    98144  47.5699
# 21605        2520              0      2014             0    98056  47.5137
# 21606        2600            910      2009             0    98136  47.5537
# 21607        1180            130      2008             0    98116  47.5773
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21603 -121.881           2270        5731
# 21604 -122.288           1400        1230
# 21605 -122.167           2520        6023
# 21606 -122.398           2050        6200
# 21607 -122.409           1330        1265
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [10 rows x 21 columns]

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
sns.scatterplot(x = 'sqft_living', y = 'price', data = house_df)
# Out:
# <AxesSubplot: xlabel='sqft_living', ylabel='price'>

# %%
house_df.hist(bins = 20, figsize = (20,20), color = 'r');

# %%
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(house_df.corr(), annot = True)
# Out:
# C:\Users\taylo\AppData\Local\Temp\ipykernel_5772\1147104236.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(house_df.corr(), annot = True)
# <AxesSubplot: >

# %%
house_df_sample = house_df[ ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'yr_built']   ]

# %%
house_df_sample
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  sqft_above  \
# 0      221900.0         3       1.00         1180      5650        1180
# 1      538000.0         3       2.25         2570      7242        2170
# 2      180000.0         2       1.00          770     10000         770
# 3      604000.0         4       3.00         1960      5000        1050
# 4      510000.0         3       2.00         1680      8080        1680
# ...         ...       ...        ...          ...       ...         ...
# 21608  360000.0         3       2.50         1530      1131        1530
# 21609  400000.0         4       2.50         2310      5813        2310
# 21610  402101.0         2       0.75         1020      1350        1020
# 21611  400000.0         3       2.50         1600      2388        1600
# 21612  325000.0         2       0.75         1020      1076        1020
#
#        sqft_basement  yr_built
# 0                  0      1955
# 1                400      1951
# 2                  0      1933
# 3                910      1965
# 4                  0      1987
# ...              ...       ...
# 21608              0      2009
# 21609              0      2014
# 21610              0      2009
# 21611              0      2004
# 21612              0      2008
#
# [21613 rows x 8 columns]

# %%
sns.pairplot(house_df_sample)

# %%
selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

# %%
X = house_df[selected_features]

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0             3       1.00         1180      5650     1.0        1180
# 1             3       2.25         2570      7242     2.0        2170
# 2             2       1.00          770     10000     1.0         770
# 3             4       3.00         1960      5000     1.0        1050
# 4             3       2.00         1680      8080     1.0        1680
# ...         ...        ...          ...       ...     ...         ...
# 21608         3       2.50         1530      1131     3.0        1530
# 21609         4       2.50         2310      5813     2.0        2310
# 21610         2       0.75         1020      1350     2.0        1020
# 21611         3       2.50         1600      2388     2.0        1600
# 21612         2       0.75         1020      1076     2.0        1020
#
#        sqft_basement
# 0                  0
# 1                400
# 2                  0
# 3                910
# 4                  0
# ...              ...
# 21608              0
# 21609              0
# 21610              0
# 21611              0
# 21612              0
#
# [21613 rows x 7 columns]

# %%
y = house_df['price']

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
X.shape
# Out:
# (21613, 7)

# %%
y.shape
# Out:
# (21613,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.        , 0.09758772,
#         0.        ],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.4       , 0.20614035,
#         0.08298755],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.05263158,
#         0.        ],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.4       , 0.14364035,
#         0.        ],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ]])

# %%
X_scaled.shape
# Out:
# (21613, 7)

# %%
scaler.data_max_
# Out:
# array([3.300000e+01, 8.000000e+00, 1.354000e+04, 1.651359e+06,
#        3.500000e+00, 9.410000e+03, 4.820000e+03])

# %%
scaler.data_min_
# Out:
# array([  0.,   0., 290., 520.,   1., 290.,   0.])

# %%
y = y.values.reshape(-1,1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
X_train.shape
# Out:
# (16209, 7)

# %%
X_test.shape
# Out:
# (5404, 7)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(100, input_dim = 7, activation = 'relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 100)               800
#
#  dense_22 (Dense)            (None, 100)               10100
#
#  dense_23 (Dense)            (None, 100)               10100
#
#  dense_24 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 21,101
# Trainable params: 21,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 2/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 3/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 4/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 5/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 6/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9194e-04 - val_loss: 0.0010
# Epoch 7/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9077e-04 - val_loss: 0.0011
# Epoch 8/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8320e-04 - val_loss: 9.9517e-04
# Epoch 9/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.9206e-04 - val_loss: 9.9710e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6884e-04 - val_loss: 0.0010
# Epoch 11/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.8145e-04 - val_loss: 0.0010
# Epoch 12/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7333e-04 - val_loss: 0.0010
# Epoch 13/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6894e-04 - val_loss: 0.0010
# Epoch 14/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7982e-04 - val_loss: 9.9589e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6743e-04 - val_loss: 0.0010
# Epoch 16/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.6130e-04 - val_loss: 0.0010
# Epoch 17/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.6567e-04 - val_loss: 0.0010
# Epoch 18/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5551e-04 - val_loss: 0.0010
# Epoch 19/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4333e-04 - val_loss: 0.0011
# Epoch 20/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.6151e-04 - val_loss: 0.0010
# Epoch 21/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5810e-04 - val_loss: 0.0010
# Epoch 22/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5879e-04 - val_loss: 0.0011
# Epoch 23/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5425e-04 - val_loss: 0.0010
# Epoch 24/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4985e-04 - val_loss: 0.0010
# Epoch 25/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5053e-04 - val_loss: 0.0011
# Epoch 26/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4967e-04 - val_loss: 0.0010
# Epoch 27/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5000e-04 - val_loss: 0.0010
# Epoch 28/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5052e-04 - val_loss: 9.9476e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4936e-04 - val_loss: 0.0010
# Epoch 30/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3252e-04 - val_loss: 0.0010
# Epoch 31/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3071e-04 - val_loss: 0.0011
# Epoch 32/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3387e-04 - val_loss: 0.0011
# Epoch 33/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.7731e-04 - val_loss: 9.9812e-04
# Epoch 34/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.5881e-04 - val_loss: 0.0011
# Epoch 35/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4279e-04 - val_loss: 0.0010
# Epoch 36/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4236e-04 - val_loss: 0.0010
# Epoch 37/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3536e-04 - val_loss: 0.0011
# Epoch 38/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2336e-04 - val_loss: 0.0011
# Epoch 39/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3995e-04 - val_loss: 0.0011
# Epoch 40/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.4383e-04 - val_loss: 0.0011
# Epoch 41/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1848e-04 - val_loss: 0.0010
# Epoch 42/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.3159e-04 - val_loss: 0.0010
# Epoch 43/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1838e-04 - val_loss: 0.0010
# Epoch 44/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2655e-04 - val_loss: 0.0010
# Epoch 45/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1806e-04 - val_loss: 0.0010
# Epoch 46/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2133e-04 - val_loss: 0.0010
# Epoch 47/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1511e-04 - val_loss: 0.0011
# Epoch 48/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.2798e-04 - val_loss: 0.0010
# Epoch 49/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0954e-04 - val_loss: 0.0011
# Epoch 50/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0338e-04 - val_loss: 0.0011
# Epoch 51/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.1740e-04 - val_loss: 0.0011
# Epoch 52/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1840e-04 - val_loss: 0.0011
# Epoch 53/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0883e-04 - val_loss: 0.0011
# Epoch 54/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.1900e-04 - val_loss: 0.0011
# Epoch 55/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0468e-04 - val_loss: 0.0010
# Epoch 56/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0921e-04 - val_loss: 0.0010
# Epoch 57/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0241e-04 - val_loss: 0.0010
# Epoch 58/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0879e-04 - val_loss: 0.0011
# Epoch 59/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0770e-04 - val_loss: 0.0011
# Epoch 60/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0146e-04 - val_loss: 0.0011
# Epoch 61/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0353e-04 - val_loss: 0.0010
# Epoch 62/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9674e-04 - val_loss: 0.0010
# Epoch 63/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9305e-04 - val_loss: 0.0010
# Epoch 64/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0227e-04 - val_loss: 0.0010
# Epoch 65/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9872e-04 - val_loss: 0.0010
# Epoch 66/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8764e-04 - val_loss: 0.0010
# Epoch 67/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0134e-04 - val_loss: 0.0010
# Epoch 68/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0519e-04 - val_loss: 0.0011
# Epoch 69/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0675e-04 - val_loss: 0.0010
# Epoch 70/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9206e-04 - val_loss: 0.0011
# Epoch 71/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8344e-04 - val_loss: 0.0011
# Epoch 72/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8227e-04 - val_loss: 0.0011
# Epoch 73/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9175e-04 - val_loss: 0.0011
# Epoch 74/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8005e-04 - val_loss: 0.0010
# Epoch 75/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8506e-04 - val_loss: 0.0011
# Epoch 76/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7751e-04 - val_loss: 0.0010
# Epoch 77/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9380e-04 - val_loss: 0.0011
# Epoch 78/100
# 260/260 [==============================] - 1s 3ms/step - loss: 9.0363e-04 - val_loss: 0.0010
# Epoch 79/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.9182e-04 - val_loss: 0.0010
# Epoch 80/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.8956e-04 - val_loss: 0.0010
# Epoch 81/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6944e-04 - val_loss: 0.0010
# Epoch 82/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7314e-04 - val_loss: 0.0011
# Epoch 83/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6934e-04 - val_loss: 0.0011
# Epoch 84/100
# 260/260 [==============================] - 1s 4ms/step - loss: 8.8382e-04 - val_loss: 0.0011
# Epoch 85/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7549e-04 - val_loss: 0.0011
# Epoch 86/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7566e-04 - val_loss: 0.0011
# Epoch 87/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7405e-04 - val_loss: 0.0010
# Epoch 88/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7577e-04 - val_loss: 0.0010
# Epoch 89/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7928e-04 - val_loss: 0.0010
# Epoch 90/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7072e-04 - val_loss: 0.0011
# Epoch 91/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7750e-04 - val_loss: 0.0011
# Epoch 92/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7892e-04 - val_loss: 0.0011
# Epoch 93/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.7349e-04 - val_loss: 0.0011
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6184e-04 - val_loss: 0.0011
# Epoch 95/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6906e-04 - val_loss: 0.0010
# Epoch 96/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6850e-04 - val_loss: 0.0011
# Epoch 97/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6322e-04 - val_loss: 0.0011
# Epoch 98/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6646e-04 - val_loss: 0.0010
# Epoch 99/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6520e-04 - val_loss: 0.0011
# Epoch 100/100
# 260/260 [==============================] - 1s 3ms/step - loss: 8.6604e-04 - val_loss: 0.0010

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(100, input_dim = 7, activation = 'relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(1, activation = 'linear'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 100)               800
#
#  dense_26 (Dense)            (None, 100)               10100
#
#  dense_27 (Dense)            (None, 100)               10100
#
#  dense_28 (Dense)            (None, 200)               20200
#
#  dense_29 (Dense)            (None, 1)                 201
#
# =================================================================
# Total params: 41,401
# Trainable params: 41,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
# 'bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement'
X_test_1 = np.array([[ 4, 3, 1960, 5000, 1, 2000, 3000 ]])

scaler_1 = MinMaxScaler()
X_test_scaled_1 = scaler_1.fit_transform(X_test_1)

y_predict_1 = model.predict(X_test_scaled_1)

y_predict_1 = scaler.inverse_transform(y_predict_1)
y_predict_1
# Out:
# 1/1 [==============================] - 0s 111ms/step
# array([[75000.]], dtype=float32)

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 169/169 [==============================] - 0s 2ms/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 5404

# %%
k
# Out:
# 7

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 457440.611
# MSE = 209251912881.33023
# MAE = 316425.9751139202
# R2 = -0.569456249444344
# Adjusted R2 = -0.5714922379072997

# %%
selected_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'yr_built', 
'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

X = house_df[selected_features]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
y = house_df['price']

# %%
y = y.values.reshape(-1,1)
y_scaled = scaler.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(10, input_dim = 19, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'linear'))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, verbose = 1, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 1s 3ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 2/100
# 260/260 [==============================] - 1s 2ms/step - loss: 0.0012 - val_loss: 9.0840e-04
# Epoch 3/100
# 260/260 [==============================] - 1s 2ms/step - loss: 9.7466e-04 - val_loss: 8.1561e-04
# Epoch 4/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.7768e-04 - val_loss: 7.3505e-04
# Epoch 5/100
# 260/260 [==============================] - 1s 2ms/step - loss: 8.2202e-04 - val_loss: 6.9617e-04
# Epoch 6/100
# 260/260 [==============================] - 1s 2ms/step - loss: 7.7165e-04 - val_loss: 6.6951e-04
# Epoch 7/100
# 260/260 [==============================] - 1s 2ms/step - loss: 7.2975e-04 - val_loss: 6.3329e-04
# Epoch 8/100
# 260/260 [==============================] - 1s 2ms/step - loss: 6.8407e-04 - val_loss: 6.0028e-04
# Epoch 9/100
# 260/260 [==============================] - 1s 2ms/step - loss: 6.5328e-04 - val_loss: 5.6729e-04
# Epoch 10/100
# 260/260 [==============================] - 1s 2ms/step - loss: 6.2422e-04 - val_loss: 5.5305e-04
# Epoch 11/100
# 260/260 [==============================] - 1s 2ms/step - loss: 6.0357e-04 - val_loss: 6.5859e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.8699e-04 - val_loss: 5.1482e-04
# Epoch 13/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.7454e-04 - val_loss: 5.0466e-04
# Epoch 14/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.6547e-04 - val_loss: 5.0666e-04
# Epoch 15/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.5822e-04 - val_loss: 5.1174e-04
# Epoch 16/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.5451e-04 - val_loss: 5.0198e-04
# Epoch 17/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.4641e-04 - val_loss: 4.9639e-04
# Epoch 18/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.4333e-04 - val_loss: 4.8191e-04
# Epoch 19/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.3845e-04 - val_loss: 4.8097e-04
# Epoch 20/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.2980e-04 - val_loss: 4.7571e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.2090e-04 - val_loss: 5.1912e-04
# Epoch 22/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.1807e-04 - val_loss: 5.0076e-04
# Epoch 23/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.2041e-04 - val_loss: 4.7143e-04
# Epoch 24/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.1420e-04 - val_loss: 4.6852e-04
# Epoch 25/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.1197e-04 - val_loss: 4.6503e-04
# Epoch 26/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.0855e-04 - val_loss: 4.5956e-04
# Epoch 27/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.0315e-04 - val_loss: 5.0486e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 2ms/step - loss: 5.0900e-04 - val_loss: 4.4981e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.9738e-04 - val_loss: 4.4877e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.9893e-04 - val_loss: 4.4156e-04
# Epoch 31/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.8936e-04 - val_loss: 4.8178e-04
# Epoch 32/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.8518e-04 - val_loss: 4.4279e-04
# Epoch 33/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.8311e-04 - val_loss: 4.3892e-04
# Epoch 34/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.8388e-04 - val_loss: 5.7421e-04
# Epoch 35/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.8244e-04 - val_loss: 4.2177e-04
# Epoch 36/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.7077e-04 - val_loss: 4.2321e-04
# Epoch 37/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.6668e-04 - val_loss: 4.0969e-04
# Epoch 38/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.5180e-04 - val_loss: 4.2273e-04
# Epoch 39/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.5184e-04 - val_loss: 4.3065e-04
# Epoch 40/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.4430e-04 - val_loss: 4.1548e-04
# Epoch 41/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.3981e-04 - val_loss: 3.9605e-04
# Epoch 42/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.3129e-04 - val_loss: 4.0702e-04
# Epoch 43/100
# 260/260 [==============================] - 1s 3ms/step - loss: 4.2737e-04 - val_loss: 3.8714e-04
# Epoch 44/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.2664e-04 - val_loss: 4.4342e-04
# Epoch 45/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.2413e-04 - val_loss: 3.7939e-04
# Epoch 46/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.2462e-04 - val_loss: 3.7341e-04
# Epoch 47/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.1852e-04 - val_loss: 3.7590e-04
# Epoch 48/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.1067e-04 - val_loss: 3.6694e-04
# Epoch 49/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.0603e-04 - val_loss: 3.6428e-04
# Epoch 50/100
# 260/260 [==============================] - 1s 2ms/step - loss: 4.0814e-04 - val_loss: 3.9398e-04
# Epoch 51/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.9766e-04 - val_loss: 3.8302e-04
# Epoch 52/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.9265e-04 - val_loss: 4.0906e-04
# Epoch 53/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.9803e-04 - val_loss: 3.8691e-04
# Epoch 54/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.9567e-04 - val_loss: 3.5889e-04
# Epoch 55/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.8590e-04 - val_loss: 3.6243e-04
# Epoch 56/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.8487e-04 - val_loss: 3.7252e-04
# Epoch 57/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.8595e-04 - val_loss: 3.5168e-04
# Epoch 58/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.8508e-04 - val_loss: 3.5710e-04
# Epoch 59/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.8145e-04 - val_loss: 3.9494e-04
# Epoch 60/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.8296e-04 - val_loss: 3.6374e-04
# Epoch 61/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.7531e-04 - val_loss: 3.5427e-04
# Epoch 62/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.7698e-04 - val_loss: 3.5774e-04
# Epoch 63/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.7422e-04 - val_loss: 3.6049e-04
# Epoch 64/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6617e-04 - val_loss: 3.5570e-04
# Epoch 65/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6627e-04 - val_loss: 3.5303e-04
# Epoch 66/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6743e-04 - val_loss: 3.7401e-04
# Epoch 67/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6530e-04 - val_loss: 3.3907e-04
# Epoch 68/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6150e-04 - val_loss: 3.4863e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6745e-04 - val_loss: 3.4732e-04
# Epoch 70/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6039e-04 - val_loss: 3.3755e-04
# Epoch 71/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5471e-04 - val_loss: 3.5768e-04
# Epoch 72/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6070e-04 - val_loss: 3.7458e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5743e-04 - val_loss: 3.5116e-04
# Epoch 74/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5786e-04 - val_loss: 3.4333e-04
# Epoch 75/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5479e-04 - val_loss: 3.3327e-04
# Epoch 76/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.6109e-04 - val_loss: 3.3444e-04
# Epoch 77/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5152e-04 - val_loss: 3.3550e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4805e-04 - val_loss: 3.3898e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5039e-04 - val_loss: 3.4466e-04
# Epoch 80/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5058e-04 - val_loss: 3.3242e-04
# Epoch 81/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4559e-04 - val_loss: 3.4058e-04
# Epoch 82/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.5119e-04 - val_loss: 3.5308e-04
# Epoch 83/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4853e-04 - val_loss: 3.3464e-04
# Epoch 84/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4686e-04 - val_loss: 3.2414e-04
# Epoch 85/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3921e-04 - val_loss: 3.3395e-04
# Epoch 86/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4531e-04 - val_loss: 3.5975e-04
# Epoch 87/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4691e-04 - val_loss: 3.3765e-04
# Epoch 88/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4716e-04 - val_loss: 3.5734e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4240e-04 - val_loss: 3.2440e-04
# Epoch 90/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4319e-04 - val_loss: 3.6057e-04
# Epoch 91/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4540e-04 - val_loss: 3.3458e-04
# Epoch 92/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3593e-04 - val_loss: 3.2836e-04
# Epoch 93/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3820e-04 - val_loss: 3.2519e-04
# Epoch 94/100
# 260/260 [==============================] - 1s 3ms/step - loss: 3.4319e-04 - val_loss: 3.2966e-04
# Epoch 95/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3798e-04 - val_loss: 3.1851e-04
# Epoch 96/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.4270e-04 - val_loss: 3.5358e-04
# Epoch 97/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3829e-04 - val_loss: 3.3149e-04
# Epoch 98/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3248e-04 - val_loss: 3.2163e-04
# Epoch 99/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3405e-04 - val_loss: 3.3483e-04
# Epoch 100/100
# 260/260 [==============================] - 1s 2ms/step - loss: 3.3525e-04 - val_loss: 3.2035e-04

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.ylabel('Training and Validation Loss')
plt.xlabel('Epoch number')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel("Model Predictions")
plt.ylabel("True Value (ground Truth)")
plt.title('Linear Regression Predictions')
plt.show()
# Out:
# 169/169 [==============================] - 0s 1ms/step

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 142113.181
# MSE = 20196156086.78774
# MAE = 84729.25596201887
# R2 = 0.8489899731620333
# Adjusted R2 = 0.8487940743132812

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(10, input_dim = 19, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(200, activation = 'relu'))
model.add(Dense(200, activation = 'relu'))

model.add(Dense(1, activation = 'linear'))
